# %% [markdown]
# <a href="https://colab.research.google.com/github/Rudy1o1/COMP-593/blob/main/LAB4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6bd801c0-d159-4f24-a2f6-98ccbde7c0b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bd801c0-d159-4f24-a2f6-98ccbde7c0b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network (3).db to social_network (3).db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network (3).db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                         user_id integer NOT NULL,
                         friend_id integer NOT NULL,
                         FOREIGN KEY (user_id) REFERENCES people (id),
                         FOREIGN KEY (friend_id) REFERENCES people (id)
                        );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network (3).db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Complete the below query
query =  """INSERT INTO relationships (user_id, friend_id)
            values(?,?);"""

for _ in range(1000):

  user_id=randrange(1,1001)

  friend_id= user_id 

  while friend_id== user_id:
    friend_id=randrange(1,1001)
  
  args = (user_id, friend_id)
  #Execute the query
  myCursor.execute(query, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
import sqlite3
from pprint import pprint 

myConnection = sqlite3.connect('social_network (3).db')
myCursor = myConnection.cursor()

#Complete the below query
query =  """SELECT people.name, COUNT(relationships.id) FROM relationships
            LEFT JOIN people ON relationships.user_id = people.id 
            GROUP BY relationships.user_id;
         """

myCursor.execute(query)
results = myCursor.fetchall()
pprint(results)

myConnection.close()

file = open('report.txt', mode='w')

for results in results:

  file.write(str(results[0]))
 
  file.write(str(results[1]))
  file.write("\n")
file.close()
# Out:
# [('Jake', 1),
#  ('Ryan', 1),
#  ('Rudy', 2),
#  ('Michelle Mitchell', 2),
#  ('Jerry Murphy', 1),
#  ('Maria Harris', 1),
#  ('Jessica Dixon', 1),
#  ('Laurie Moore', 2),
#  ('Nicole Hamilton', 1),
#  ('Donald Bowen', 1),
#  ('Brian Phillips', 3),
#  ('Tasha Perez', 1),
#  ('Raymond Russell', 1),
#  ('Kristina Goodman', 2),
#  ('Ashley Gallagher', 1),
#  ('Adam Simmons', 1),
#  ('Susan Horton DVM', 1),
#  ('William Richards', 1),
#  ('Cynthia Knox', 1),
#  ('Elizabeth Pope', 2),
#  ('Robert Cole', 3),
#  ('Darrell Williams', 1),
#  ('Priscilla Woods', 1),
#  ('Jonathan Jones', 1),
#  ('Michelle Adkins', 1),
#  ('Shelly Gonzalez', 3),
#  ('Dr. Jack Smith', 1),
#  ('Christopher Flores', 2),
#  ('Isabella White', 1),
#  ('Gregory Greer', 1),
#  ('Daniel Porter', 1),
#  ('Kristy Cox', 3),
#  ('Jenny Berg', 1),
#  ('Diane Moore', 2),
#  ('Melissa Perez', 1),
#  ('Michael Dixon', 2),
#  ('Heidi Anderson', 2),
#  ('Randy Fernandez', 1),
#  ('Beverly Smith', 1),
#  ('Jonathan Brown', 1),
#  ('Christopher Richards', 1),
#  ('Nicholas Walters', 2),
#  ('Connie Peterson', 2),
#  ('Paul Miranda PhD', 1),
#  ('Sara Gallegos', 3),
#  ('Jonathan Henderson', 3),
#  ('Kimberly Ramsey', 1),
#  ('Ronald Smith', 1),
#  ('Sean Bradford', 1),
#  ('Sarah Smith', 4),
#  ('Jason Myers', 1),
#  ('Paul Ortega', 1),
#  ('Alan Graham', 2),
#  ('Ryan Espinoza', 3),
#  ('Mary Sims', 1),
#  ('Dan Brown', 3),
#  ('Amy Clark', 1),
#  ('Kyle Lara', 1),
#  ('Christopher Blair', 2),
#  ('Mrs. Meghan Bennett', 1),
#  ('Heather Rocha', 2),
#  ('Adam Green', 2),
#  ('George Delgado', 2),
#  ('Kayla Lee', 1),
#  ('Ruth Mccoy', 3),
#  ('Brian Moon', 2),
#  ('Mary Vasquez', 1),
#  ('Benjamin Reed', 1),
#  ('Elizabeth Johnson DVM', 1),
#  ('John Martin', 1),
#  ('Lance Shepherd', 2),
#  ('Adrian Barker', 1),
#  ('Francis Moore', 1),
#  ('Monica Jefferson', 2),
#  ('Kimberly Hunt', 1),
#  ('Austin Diaz', 3),
#  ('Grace Kramer', 1),
#  ('Theresa Proctor', 1),
#  ('Charles Cole', 1),
#  ('Timothy Mckinney', 3),
#  ('Sean Maynard', 1),
#  ('Haley Willis', 4),
#  ('James Ramos', 1),
#  ('Amanda Graves', 2),
#  ('Kristi Cox', 1),
#  ('Dr. Jean Lambert', 1),
#  ('Paul Wilson', 1),
#  ('Cindy Cortez', 1),
#  ('Sandra Diaz', 1),
#  ('Kristina Williams', 1),
#  ('Brittany Banks', 2),
#  ('Tim Kaiser', 1),
#  ('Stephanie Thompson', 1),
#  ('Melissa Thompson', 1),
#  ('Allison Horton', 1),
#  ('Valerie Mack', 1),
#  ('Paula Garrett', 1),
#  ('Katie Wells', 2),
#  ('George Lucero', 1),
#  ('Cheyenne Hutchinson', 2),
#  ('Miss Sandra Wyatt', 2),
#  ('David Carter', 2),
#  ('Tiffany Colon', 1),
#  ('Steven Lopez', 1),
#  ('Aaron Valdez', 1),
#  ('Jerry Smith', 1),
#  ('Cheryl Welch', 3),
#  ('Joseph Lewis', 2),
#  ('Benjamin Myers', 1),
#  ('Kelly Wallace', 2),
#  ('Scott Reyes', 1),
#  ('Christopher Reeves', 1),
#  ('Dr. Sherry Rodriguez', 2),
#  ('Lauren Lewis', 2),
#  ('Ryan Schmidt', 1),
#  ('Jacob Clark', 1),
#  ('Emma Rose', 1),
#  ('Michelle Miller', 1),
#  ('Julie Spears', 1),
#  ('Chad Kelley', 2),
#  ('Dana Baldwin', 2),
#  ('Jacqueline Blackwell', 1),
#  ('Michael Martin', 1),
#  ('Kimberly Lawson', 2),
#  ('Crystal Sanchez', 3),
#  ('John Harper', 1),
#  ('Shawn Bradley', 1),
#  ('Jennifer Miller', 1),
#  ('Rachel Garcia', 3),
#  ('Jennifer Chang', 2),
#  ('Alicia Lewis', 2),
#  ('Rebecca Chang DDS', 2),
#  ('Brett Lewis', 3),
#  ('Brett Chaney', 1),
#  ('Chloe Olsen', 1),
#  ('Kyle West', 1),
#  ('Tracy Macdonald', 2),
#  ('Abigail Mckee', 2),
#  ('Brian Davis', 2),
#  ('Joanne Rios', 1),
#  ('Heather Stephens', 2),
#  ('Sydney Gibson', 2),
#  ('Robert Valentine', 1),
#  ('Alexander Lopez', 1),
#  ('Deborah Blackburn', 3),
#  ('Kenneth Armstrong', 1),
#  ('Kayla Oconnor', 2),
#  ('Cynthia Cordova DDS', 4),
#  ('Ashley Ruiz', 1),
#  ('Nina Hansen', 2),
#  ('Jade Moore', 1),
#  ('Adam Graham', 1),
#  ('Timothy Brown', 3),
#  ('Linda Robinson', 1),
#  ('Miguel Watson', 1),
#  ('Samuel Jensen', 1),
#  ('Cynthia Townsend', 2),
#  ('James Berg', 2),
#  ('Emily Miller', 1),
#  ('Joseph Weber', 1),
#  ('Robert Moore', 2),
#  ('Jonathan Parker', 2),
#  ('David Love', 1),
#  ('Douglas Scott', 1),
#  ('Lucas Gutierrez', 1),
#  ('Jesse Crane', 2),
#  ('Kathleen Smith', 1),
#  ('Michelle Watkins', 1),
#  ('Kristen Kelley', 1),
#  ('Kevin Spence', 1),
#  ('Stephen Ryan', 1),
#  ('Matthew Vargas', 1),
#  ('Robert Johnson', 1),
#  ('Mary Miller', 1),
#  ('Dylan Hernandez', 1),
#  ('Andrea Burnett PhD', 1),
#  ('Anthony Thompson', 1),
#  ('Ana Palmer', 1),
#  ('David Ward', 1),
#  ('John Torres', 1),
#  ('Karen King', 4),
#  ('Harold Johnson', 1),
#  ('Debbie Obrien', 2),
#  ('Maria Frye', 3),
#  ('Michael Peterson', 1),
#  ('Lindsay Benson', 1),
#  ('Vanessa Davis', 2),
#  ('Tyler Nicholson', 2),
#  ('Maria Woodard', 1),
#  ('Jaclyn Lane', 1),
#  ('Mr. Timothy Woods', 1),
#  ('Richard Adams', 1),
#  ('Lindsey Marks', 1),
#  ('Patrick Montoya', 1),
#  ('Brian Berg', 1),
#  ('Andrea Bradley', 2),
#  ('Pamela Hall', 1),
#  ('Paul Myers', 2),
#  ('Bruce Young', 1),
#  ('Sheila Mccarthy', 1),
#  ('Amanda Reed', 1),
#  ('Vincent Henry', 3),
#  ('Kathleen Griffin', 1),
#  ('William Soto', 1),
#  ('Scott Johnson', 1),
#  ('Allison Day', 2),
#  ('Kathleen Brown', 1),
#  ('Michael Taylor', 4),
#  ('Brandon Bonilla', 1),
#  ('Kathleen James', 2),
#  ('Samantha Willis', 1),
#  ('Adam Mitchell', 1),
#  ('Sheila Franco', 4),
#  ('Alan Allison', 1),
#  ('Whitney Buckley', 1),
#  ('Mary Durham', 1),
#  ('Taylor Wood', 2),
#  ('Bradley Wiley', 2),
#  ('Brenda Matthews', 2),
#  ('Leah Glover', 1),
#  ('Ronald Gilbert', 1),
#  ('Christine Bond', 1),
#  ('Holly Bentley', 4),
#  ('Austin Beard', 1),
#  ('Catherine Williams', 1),
#  ('Andrew Williams', 1),
#  ('David Dawson', 1),
#  ('Barbara Lamb', 1),
#  ('Daniel Leonard', 3),
#  ('Christian Barker', 1),
#  ('Ms. Vicki Moreno', 1),
#  ('Dr. Joe Hernandez', 1),
#  ('Mary Hernandez', 1),
#  ('Christopher Stevenson', 1),
#  ('Valerie Bowen', 2),
#  ('Tyler Kim', 2),
#  ('Jennifer Fleming', 2),
#  ('Alice Garner', 2),
#  ('Rebecca Mcclure', 2),
#  ('Brian Perkins', 1),
#  ('Danielle Clark', 1),
#  ('Joseph Walsh', 1),
#  ('Joseph Young', 3),
#  ('Paula Santiago', 1),
#  ('Gary Taylor', 1),
#  ('John Roberts', 2),
#  ('Henry Howard', 2),
#  ('Nicholas Lopez', 1),
#  ('Carol Hubbard', 1),
#  ('Kenneth Ortiz', 1),
#  ('Joel Cruz', 2),
#  ('Tammy Burns', 3),
#  ('Sean Jennings', 2),
#  ('Andrew Pearson', 1),
#  ('Mr. Chris Nichols DVM', 2),
#  ('Gregory Prince', 2),
#  ('Anthony Chavez', 1),
#  ('Courtney Love', 1),
#  ('Christina Rojas', 1),
#  ('Timothy Lindsey', 2),
#  ('Bailey Acevedo', 1),
#  ('Patrick Gutierrez', 2),
#  ('Shawn Mitchell', 1),
#  ('Elizabeth Snyder', 1),
#  ('Alexandra Jones', 1),
#  ('Sara Patel', 4),
#  ('Steven James', 2),
#  ('Elaine Adams MD', 1),
#  ('Jay Wong', 2),
#  ('Angela Carson', 1),
#  ('Michelle Perkins', 1),
#  ('Rebecca Williams', 2),
#  ('Dustin Davenport', 2),
#  ('Christopher Keller', 2),
#  ('Joshua Hampton', 2),
#  ('Denise Carter', 1),
#  ('Charles Mitchell', 1),
#  ('Sherri Jones', 1),
#  ('Tom Dyer', 1),
#  ('Melissa Garcia', 3),
#  ('Alicia Dunn', 1),
#  ('Adam Jones', 1),
#  ('Daniel Pena', 5),
#  ('Lisa Brewer', 1),
#  ('Bryce Davis', 1),
#  ('Jerry Robinson', 1),
#  ('Brandon White', 3),
#  ('Jillian Arias', 2),
#  ('Jesse Carlson', 1),
#  ('Sean Russell', 2),
#  ('Juan Bell', 1),
#  ('Lucas Todd', 2),
#  ('Misty Day', 3),
#  ('Erin Smith', 3),
#  ('Kellie Garza', 1),
#  ('Tracey Bean', 1),
#  ('Holly Schneider', 2),
#  ('Alan Brown', 2),
#  ('Kayla Arias', 1),
#  ('Victoria Silva', 1),
#  ('Courtney Solis', 1),
#  ('Michael Garcia', 1),
#  ('Marcus Butler', 3),
#  ('Brandon Reed II', 2),
#  ('Jamie Medina', 3),
#  ('Roberta Welch', 1),
#  ('Dean Carter', 2),
#  ('Brenda Schwartz', 1),
#  ('Aaron Santos', 2),
#  ('Pamela George', 3),
#  ('Carol Bird', 1),
#  ('Jessica Galvan', 3),
#  ('Joshua Wall MD', 1),
#  ('Patrick Brooks', 2),
#  ('Mary Hicks', 1),
#  ('Mr. Brian Perry', 1),
#  ('Matthew Wood', 1),
#  ('Carl Knapp', 2),
#  ('Calvin Wang', 3),
#  ('Phillip Martin', 2),
#  ('Anthony Harvey', 1),
#  ('Carlos Martinez', 1),
#  ('Brandon Schroeder', 1),
#  ('Megan Mooney', 1),
#  ('Christina Smith', 1),
#  ('Kayla Singh', 4),
#  ('Jeffrey Garner', 3),
#  ('Andrew Zimmerman', 2),
#  ('Brandi Taylor', 2),
#  ('Ronald Mcdonald', 1),
#  ('Brian Thompson', 1),
#  ('Kelly Frazier', 1),
#  ('Kathryn Whitney', 1),
#  ('Cynthia Rodriguez', 1),
#  ('Lee Fisher', 2),
#  ('John Hunt', 1),
#  ('Christopher Smith', 1),
#  ('Lori Durham', 1),
#  ('Jeffrey Ward', 1),
#  ('Mrs. Maria Reed', 1),
#  ('Tracy Haynes', 1),
#  ('Kelly Bailey', 1),
#  ('Robert Wilson', 3),
#  ('Stuart Garcia', 1),
#  ('Gabriel Cook', 1),
#  ('Albert Schmidt', 1),
#  ('Amy Jacobs', 3),
#  ('Karen Payne', 2),
#  ('Richard Davis', 1),
#  ('Charles Williams DVM', 1),
#  ('Craig Webb', 2),
#  ('Benjamin Waters', 1),
#  ('Debra Wells', 1),
#  ('Leslie Miller', 1),
#  ('Gary Rogers', 1),
#  ('Eric Drake', 1),
#  ('Andrea Lane', 3),
#  ('Angelica Galloway', 2),
#  ('Ryan Clark', 1),
#  ('Kelly Terry', 2),
#  ('Thomas Wong', 1),
#  ('Raymond Lee', 1),
#  ('Eric Mathis', 1),
#  ('Justin Fowler', 1),
#  ('Donald Scott', 1),
#  ('Sheila Valenzuela', 1),
#  ('Devon Aguilar', 2),
#  ('Sandra Briggs', 1),
#  ('Patrick Miller', 1),
#  ('David Bailey', 1),
#  ('Maria Lee', 1),
#  ('Jonathon Wiley', 3),
#  ('Michael Patel', 1),
#  ('Bradley James', 1),
#  ('Grant Salazar', 2),
#  ('James Goodwin', 2),
#  ('Danielle Reyes', 1),
#  ('Nicole Compton', 2),
#  ('Jonathan Moss', 2),
#  ('Kevin Pierce', 1),
#  ('Kevin Fisher', 1),
#  ('Linda Martin', 1),
#  ('Samuel Smith', 1),
#  ('Michelle Schwartz', 1),
#  ('Joseph Romero', 2),
#  ('Steven Allison', 2),
#  ('Keith Mccarthy', 1),
#  ('Courtney Petersen', 2),
#  ('Kelly Fisher', 1),
#  ('Marc Estrada', 2),
#  ('Scott Cooper', 1),
#  ('Charles Anderson', 1),
#  ('Susan Jenkins', 3),
#  ('Robert Walsh', 4),
#  ('Cassandra Gonzalez', 1),
#  ('Tiffany Cole', 2),
#  ('Cathy Mcclure', 1),
#  ('Brian Lynch', 1),
#  ('Elizabeth Jones', 3),
#  ('Dennis Miller', 1),
#  ('Brett Wong', 2),
#  ('Victoria Lambert', 2),
#  ('Corey Riley', 3),
#  ('David Howard', 2),
#  ('Jessica Jones', 1),
#  ('Tiffany Barnett', 1),
#  ('Brianna Mcdaniel', 1),
#  ('Christy White', 3),
#  ('Dylan Foster', 1),
#  ('Julia Nguyen', 2),
#  ('Carolyn Hall', 1),
#  ('Nicole Petty', 2),
#  ('Taylor Sanders', 3),
#  ('Emily Jensen', 1),
#  ('Jeffrey Logan', 1),
#  ('Tammy Bernard', 3),
#  ('Julian Khan', 2),
#  ('Mark Taylor', 1),
#  ('Andrea Chan', 2),
#  ('Maureen Jackson', 2),
#  ('Robert Rodriguez', 1),
#  ('Kenneth Nguyen', 1),
#  ('Carly Lowe', 2),
#  ('Julie Pugh', 1),
#  ('James Hodge', 1),
#  ('Mario Hawkins', 2),
#  ('Mary Sullivan', 1),
#  ('Matthew Taylor', 2),
#  ('Amy Smith', 1),
#  ('William Roberts', 3),
#  ('Christopher Dyer', 1),
#  ('Susan Roberts', 3),
#  ('Brooke Garrett', 1),
#  ('Tammy Franklin', 1),
#  ('Dennis Rodriguez', 1),
#  ('Brian Hood', 3),
#  ('Robert Gregory', 4),
#  ('Michael Barnes', 1),
#  ('Brian Gonzales', 2),
#  ('Kimberly Flores', 2),
#  ('Brian Murray', 2),
#  ('Monica Meyer', 2),
#  ('Timothy Marsh', 1),
#  ('Joe Davis', 4),
#  ('Heidi Hicks', 2),
#  ('Diana Sandoval', 2),
#  ('Jeffrey Khan', 4),
#  ('Daniel Rivera', 1),
#  ('James Hays', 2),
#  ('James Alexander', 2),
#  ('Ethan Taylor', 2),
#  ('Melissa Pruitt', 1),
#  ('Lisa Little', 1),
#  ('Brian Simpson', 1),
#  ('Jodi Wilkins', 2),
#  ('Francisco Shepherd', 1),
#  ('Lisa Kelly', 1),
#  ('Lori Cook', 2),
#  ('Michael Martinez', 2),
#  ('Christopher Mills', 2),
#  ('Dr. Todd Williams Jr.', 1),
#  ('Tammie Peterson', 3),
#  ('Jessica Mosley', 1),
#  ('Jeffrey Jones', 2),
#  ('Randy Anderson', 1),
#  ('Andrea Price', 2),
#  ('Desiree Beltran', 3),
#  ('Mindy House', 3),
#  ('Megan Anderson', 3),
#  ('Charles Saunders', 3),
#  ('Melissa Davies', 1),
#  ('Julia Davis', 1),
#  ('Edwin Sanchez', 1),
#  ('Lisa Carter', 2),
#  ('Matthew Ramirez', 1),
#  ('Alexander Lee', 1),
#  ('Angela Watts', 1),
#  ('Christine Patrick', 1),
#  ('Jeffery Perkins', 1),
#  ('John Martinez', 2),
#  ('David Powell', 1),
#  ('Colleen Gonzales', 2),
#  ('Virginia Maddox', 1),
#  ('Daniel Faulkner', 1),
#  ('Charles Solomon', 1),
#  ('Raymond Davis', 1),
#  ('Tyler Snyder', 1),
#  ('Marc Gomez', 2),
#  ('Linda Howell', 1),
#  ('Patrick Williams', 1),
#  ('Jerry Franklin', 3),
#  ('Nathan Moore', 2),
#  ('Morgan Smith', 1),
#  ('Christy Sullivan', 1),
#  ('Jeremy Thompson', 2),
#  ('Allen Walters', 2),
#  ('David Mitchell', 1),
#  ('William Singleton', 1),
#  ('Tina Ellison', 3),
#  ('Angela Carter', 1),
#  ('Lauren Frye', 2),
#  ('Emily Pitts', 1),
#  ('Justin Casey', 1),
#  ('John Morse', 1),
#  ('Michelle Gomez MD', 1),
#  ('Joseph Smith', 2),
#  ('Linda Ford', 1),
#  ('Kathleen Garcia', 1),
#  ('Jerry Galvan', 1),
#  ('Sean Miller', 1),
#  ('Cindy Schneider', 1),
#  ('Kristen Warren', 3),
#  ('Shawn Durham', 2),
#  ('Kyle Wong', 2),
#  ('Samantha Flowers', 1),
#  ('Christian Jones', 1),
#  ('Clarence Robinson', 2),
#  ('Andrea Campbell', 2),
#  ('Joshua Stuart', 1),
#  ('Kim Turner', 2),
#  ('Peter Jackson', 1),
#  ('Michelle Brown', 1),
#  ('Christopher Brown', 2),
#  ('John Yang', 1),
#  ('Jacob Rice', 1),
#  ('James Walker', 2),
#  ('Amanda Wood', 1),
#  ('Mark Jones', 1),
#  ('Kathryn Roberts', 1),
#  ('Jennifer Strickland', 1),
#  ('Robert Baker', 1),
#  ('Oscar Boyer', 2),
#  ('Johnathan Perez', 1),
#  ('Jennifer Rush', 1),
#  ('Margaret Coleman', 1),
#  ('Dr. Taylor Munoz', 1),
#  ('Hannah Burke', 2),
#  ('Nicholas Johnson', 1),
#  ('Robert Oliver', 1),
#  ('Joseph Briggs', 2),
#  ('Wendy Salas', 1),
#  ('Kimberly Brandt', 2),
#  ('Christopher Romero', 1),
#  ('Angela Rodriguez', 2),
#  ('Steven Mercer', 2),
#  ('Andrew Moore', 2),
#  ('Robert Sims', 1),
#  ('Kevin Terry', 1),
#  ('Thomas Martinez', 2),
#  ('Peter Turner', 1),
#  ('Courtney Gibson', 1),
#  ('David Davis', 1),
#  ('Jodi Rose', 2),
#  ('Michael Ibarra', 2),
#  ('Todd Berry', 1),
#  ('Nicole Joseph', 2),
#  ('Candice Johnson', 1),
#  ('David Jackson', 2),
#  ('Julie Holland', 1),
#  ('Howard Reyes', 1),
#  ('Ryan Cantrell', 1),
#  ('Melvin Cunningham', 1),
#  ('Jody Davis', 2),
#  ('Olivia Navarro', 2),
#  ('Vickie Nunez', 1),
#  ('Christine Turner', 1),
#  ('Taylor Harrington', 2),
#  ('Jose Mclean', 1),
#  ('Jacqueline Ortiz', 1),
#  ('Keith Owens', 1),
#  ('Austin Phillips', 1),
#  ('Philip Price', 3),
#  ('John Estes', 1),
#  ('Kevin Johnson', 1),
#  ('Mr. Dillon Carter', 3),
#  ('Stephen Newton', 2),
#  ('Mr. Francisco Rogers II', 1),
#  ('Christina Webster', 1),
#  ('Amanda Brewer', 1),
#  ('David Mitchell', 4),
#  ('Matthew Singleton', 3),
#  ('Beth Reyes', 1),
#  ('Joshua Kent', 1),
#  ('Sean Thomas', 1),
#  ('Charles Holmes', 1),
#  ('Teresa Harrell', 1),
#  ('Colin Gordon', 3),
#  ('Janice Hicks', 1),
#  ('Robert Davis', 2),
#  ('Mary Anderson', 1),
#  ('Shelby Faulkner', 1),
#  ('Mark Wilkerson', 2),
#  ('Jenna Gonzalez', 4),
#  ('Michael Anderson', 1),
#  ('Robert Williams', 3),
#  ('Sarah Perez', 1),
#  ('Brian Martinez', 1),
#  ('John Martinez', 2),
#  ('Savannah Clarke', 1),
#  ('Pamela Tanner', 2),
#  ('Jacqueline Ferguson', 2),
#  ('Joshua Thompson', 1),
#  ('Wendy Jackson', 1),
#  ('Stephanie Cortez', 1),
#  ('Michele Romero', 1),
#  ('Michelle Snyder', 1),
#  ('Timothy Johnson', 1),
#  ('Sara Heath', 1),
#  ('Tiffany Anderson', 1),
#  ('Jason Douglas', 1),
#  ('Eric Howard', 1),
#  ('Kelly Wilkinson', 1),
#  ('William Oliver', 1),
#  ('Jay Yoder', 2),
#  ('Kenneth Henry', 1),
#  ('John Carrillo', 1),
#  ('Louis Holloway', 2),
#  ('Miguel Henderson', 1),
#  ('Rebecca Watson', 1),
#  ('Joseph Sloan', 1),
#  ('Jennifer Warren', 1),
#  ('Heather White', 1),
#  ('Tony Peterson', 3),
#  ('Jacob Kane', 1),
#  ('Kelly Brown', 1),
#  ('Richard Norton', 1),
#  ('Renee Davidson', 1),
#  ('Daniel Terrell', 1),
#  ('Sara Howard', 1),
#  ('Lauren Johnson', 1),
#  ('Megan Olson', 1),
#  ('Gregory Miller', 3),
#  ('Andrea Barker', 2),
#  ('Michele Vaughn', 2),
#  ('Ernest Davis', 3),
#  ('Susan Knox', 2),
#  ('Micheal Lynch', 1),
#  ('Charles Cunningham', 1),
#  ('Timothy Turner MD', 2),
#  ('Teresa Grimes', 2),
#  ('Yesenia Hicks', 2),
#  ('Logan Snyder', 1),
#  ('Clarence Vincent', 1),
#  ('Linda Flores', 1),
#  ('Eric Sanchez', 1),
#  ('William Coleman', 2),
#  ('Julie Young', 1),
#  ('Craig Miller', 1),
#  ('Johnny Silva', 2),
#  ('Derrick Pierce', 2),
#  ('Jacob Richardson', 1)]

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
